# %%
import pandas as pd
import numpy as np
import gensim
import nltk
from nltk.corpus import stopwords
from scipy.stats import skew, kurtosis
import re
from gensim.models import Word2Vec
import gensim
from gensim.models.wrappers import FastText
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import KFold
from gensim.models import KeyedVectors

Word2Vec = KeyedVectors.load_word2vec_format('../diff_traditional/source_data/wiki.es.vec', binary=False)
# Out:
# /home/nikuailemateam/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
train = pd.read_csv('preprocessing_train.csv')
test = pd.read_csv('preprocessing_test.csv')
test['label'] = -1
test['test_id'] = range(len(test))

# %%
train.head()
# Out:
#    label                                          spa_qura1  \
# 0      0             hola hago clic en el producto recibido
# 1      0  ¡Hola Cerré la disputa el 21 de mayo de 2017 y...
# 2      0  Ordené de España a España ahora que mandan el ...
# 3      1               ¿Debo pagar impuestos personalizados
# 4      0                                No recibí mi pedido
#
#                                            spa_qura2
# 0  Compré un producto y no he recibido un correo ...
# 1  No obtuve el reembolso de mi dinero Han pasado...
# 2  Mi pedido llegó pero el color es diferente al ...
# 3                  Cómo pagar los derechos de aduana
# 4    Mi pedido muestra que no he pagado pero lo hice

# %%
print ("去掉未在word2vec中的词...")
def spa_norm_word_list(s1):
    s1 = str(s1).lower().split()
    s1 = [w for w in s1 if w in Word2Vec]
    return s1

train['spa_qura1_list'] = train['spa_qura1'].apply(spa_norm_word_list)
train['spa_qura2_list'] = train['spa_qura2'].apply(spa_norm_word_list)

test['spa_qura1_list'] = test['spa_qura1'].apply(spa_norm_word_list)
test['spa_qura2_list'] = test['spa_qura2'].apply(spa_norm_word_list)

print("去掉停用词结束...")
# Out:
# 去掉未在word2vec中的词...
# 去掉停用词结束...

# %%
print("生成embedding...")

spa_list = list(train['spa_qura1'])
spa_list.extend(list(train['spa_qura2']))
spa_list.extend(list(test['spa_qura1']))
spa_list.extend(list(test['spa_qura2']))

MAX_NB_WORDS = 200000
MAX_SEQUENCE_LENGTH = 55
EMBEDDING_DIM = 300

# 生成token词典
tokenizer = Tokenizer(num_words=MAX_NB_WORDS)
tokenizer.fit_on_texts(spa_list)

texts_1 = list(train['spa_qura1'])
texts_2 = list(train['spa_qura2'])
test_texts_1 = list(test['spa_qura1'])
test_texts_2 = list(test['spa_qura2'])

# 得到词索引,相当于把每个sentence给序列化
sequences_1 = tokenizer.texts_to_sequences(texts_1)
sequences_2 = tokenizer.texts_to_sequences(texts_2)
test_sequences_1 = tokenizer.texts_to_sequences(test_texts_1)
test_sequences_2 = tokenizer.texts_to_sequences(test_texts_2)

# number of unique words
word_index = tokenizer.word_index
print('Found %s unique tokens' % len(word_index))

# 长度不足max_length的补0
data_1 = pad_sequences(sequences_1, maxlen=MAX_SEQUENCE_LENGTH)
data_2 = pad_sequences(sequences_2, maxlen=MAX_SEQUENCE_LENGTH)

test_data_1 = pad_sequences(test_sequences_1, maxlen=MAX_SEQUENCE_LENGTH)
test_data_2 = pad_sequences(test_sequences_2, maxlen=MAX_SEQUENCE_LENGTH)

print('Preparing embedding matrix')
nb_words = min(MAX_NB_WORDS, len(word_index)) + 1
print('There are %d words' % nb_words)

# 把每个单词变成维度为EMBEDDING_DIM的向量,向量根据word2vec得到
embedding_matrix = np.zeros((nb_words, EMBEDDING_DIM))
for word, i in word_index.items():
    if word in Word2Vec:
        embedding_matrix[i] = Word2Vec[word]
# 查看哪些词没有词向量
print('Null word embeddings: %d' % np.sum(np.sum(embedding_matrix, axis=1) == 0))
# Out:
# 生成embedding...
# Found 5991 unique tokens
# Preparing embedding matrix
# There are 5992 words
# Null word embeddings: 693

# %%
#获取distance_feature
df = pd.read_csv('../diff_traditional/train.dat')
distance_feature = df[['len_char_s1','len_char_s2','fuzz_QRatio','fuzz_WRatio']]
distance_feature = np.array(distance_feature)
test_distance_feature = distance_feature[21400:]

# %%
# Out:
# 300

# %%
data_1
# Out:
# array([[   0,    0,    0, ...,  184,   16,   18],
#        [   0,    0,    0, ...,   66,  809,   21],
#        [   0,    0,    0, ..., 1451,    3,  149],
#        ...,
#        [   0,    0,    0, ...,    2, 1497,  350],
#        [   0,    0,    0, ...,    2, 1497,  350],
#        [   0,    0,    0, ...,    6,  603,  409]], dtype=int32)

# %%
from cnn_model_3 import *

# %%
#from cnn_model import *
#from matchpyramid_model import *
from keras.callbacks import EarlyStopping, ModelCheckpoint
print ("Running model")

# label = list(train_e.label)
# label.extend(list(train_s.label))
label = np.array(list(train.label))
# label = np.array(label)

folds = KFold(n_splits = 5, shuffle = False, random_state = 123)
pred_results = []
re_weight = True
val_loss_result = []
train_pred_results = []
for idx_train, idx_val in folds.split(data_1):
    data_1_train = data_1[idx_train]
    data_2_train = data_2[idx_train]
    #dis_train = distance_feature[idx_train]
    labels_train = label[idx_train]

    data_1_val = data_1[idx_val]
    data_2_val = data_2[idx_val]
    #dis_val = distance_feature[idx_val]
    labels_val = label[idx_val]
    
    Cnn = CNN3()
    model = Cnn.build_model(embedding_matrix, data_1.shape[1])
#     matchPyramid = MatchPyramid()
#     model = matchPyramid.build_model(embedding_matrix, data_1.shape[1])

    early_stopping = EarlyStopping(monitor='val_loss', patience=1)
    
    hist = model.fit([data_1_train, data_2_train],
                     labels_train, 
                     validation_data=([data_1_val, data_2_val], labels_val),
                     epochs=25,
                     batch_size=64,
                     shuffle=True, 
                     callbacks=[early_stopping],
                     verbose = 2)
    
    bst_val_score = min(hist.history['val_loss'])
    val_loss_result.append(bst_val_score)
    #model.load_weights("weights-improvement.hdf5")
    preds = model.predict([test_data_1, test_data_2], batch_size = 2048, verbose = 2)
    train_preds = model.predict([data_1_val, data_2_val], batch_size = 2048, verbose = 2)

    pred_results.append(preds)
    train_pred_results.extend(train_preds)
# Out:
# Running model
# Train on 17120 samples, validate on 4280 samples
# Epoch 1/25
#  - 191s - loss: 0.5793 - acc: 0.7316 - val_loss: 0.4597 - val_acc: 0.8063
# Epoch 2/25
#  - 189s - loss: 0.4492 - acc: 0.8031 - val_loss: 0.4107 - val_acc: 0.8250
# Epoch 3/25
#  - 188s - loss: 0.3779 - acc: 0.8345 - val_loss: 0.3741 - val_acc: 0.8423
# Epoch 4/25
#  - 187s - loss: 0.3287 - acc: 0.8562 - val_loss: 0.3671 - val_acc: 0.8512
# Epoch 5/25
#  - 187s - loss: 0.2830 - acc: 0.8744 - val_loss: 0.3637 - val_acc: 0.8481
# Epoch 6/25
#  - 188s - loss: 0.2505 - acc: 0.8938 - val_loss: 0.3654 - val_acc: 0.8537
# Train on 17120 samples, validate on 4280 samples
# Epoch 1/25
#  - 191s - loss: 0.5638 - acc: 0.7360 - val_loss: 0.5112 - val_acc: 0.7801
# Epoch 2/25
#  - 187s - loss: 0.4408 - acc: 0.8071 - val_loss: 0.4242 - val_acc: 0.8175
# Epoch 3/25
#  - 186s - loss: 0.3679 - acc: 0.8365 - val_loss: 0.4082 - val_acc: 0.8304
# Epoch 4/25
#  - 187s - loss: 0.3170 - acc: 0.8641 - val_loss: 0.3898 - val_acc: 0.8334
# Epoch 5/25
#  - 187s - loss: 0.2777 - acc: 0.8790 - val_loss: 0.3831 - val_acc: 0.8453
# Epoch 6/25
#  - 187s - loss: 0.2442 - acc: 0.8971 - val_loss: 0.3909 - val_acc: 0.8472
# Train on 17120 samples, validate on 4280 samples
# Epoch 1/25
#  - 191s - loss: 0.5817 - acc: 0.7300 - val_loss: 0.4967 - val_acc: 0.7909
# Epoch 2/25
#  - 186s - loss: 0.4462 - acc: 0.8063 - val_loss: 0.4299 - val_acc: 0.8180
# Epoch 3/25
#  - 187s - loss: 0.3768 - acc: 0.8348 - val_loss: 0.4190 - val_acc: 0.8311
# Epoch 4/25
#  - 187s - loss: 0.3220 - acc: 0.8604 - val_loss: 0.3846 - val_acc: 0.8439
# Epoch 5/25
#  - 186s - loss: 0.2777 - acc: 0.8810 - val_loss: 0.3996 - val_acc: 0.8472
# Train on 17120 samples, validate on 4280 samples
# Epoch 1/25
#  - 192s - loss: 0.5971 - acc: 0.7139 - val_loss: 0.6182 - val_acc: 0.7096
# Epoch 2/25
#  - 186s - loss: 0.4782 - acc: 0.7918 - val_loss: 0.4414 - val_acc: 0.8100
# Epoch 3/25
#  - 186s - loss: 0.4140 - acc: 0.8166 - val_loss: 0.3895 - val_acc: 0.8306
# Epoch 4/25
#  - 187s - loss: 0.3652 - acc: 0.8369 - val_loss: 0.3712 - val_acc: 0.8390
# Epoch 5/25
#  - 186s - loss: 0.3234 - acc: 0.8549 - val_loss: 0.3565 - val_acc: 0.8460
# Epoch 6/25
#  - 187s - loss: 0.2884 - acc: 0.8725 - val_loss: 0.3563 - val_acc: 0.8451
# Epoch 7/25
#  - 186s - loss: 0.2589 - acc: 0.8855 - val_loss: 0.3415 - val_acc: 0.8675
# Epoch 8/25
#  - 186s - loss: 0.2283 - acc: 0.9026 - val_loss: 0.3415 - val_acc: 0.8682
# Train on 17120 samples, validate on 4280 samples
# Epoch 1/25
#  - 192s - loss: 0.5754 - acc: 0.7256 - val_loss: 0.4776 - val_acc: 0.8000
# Epoch 2/25
#  - 186s - loss: 0.4424 - acc: 0.8055 - val_loss: 0.4141 - val_acc: 0.8171
# Epoch 3/25
#  - 186s - loss: 0.3692 - acc: 0.8352 - val_loss: 0.4023 - val_acc: 0.8318
# Epoch 4/25
#  - 184s - loss: 0.3194 - acc: 0.8591 - val_loss: 0.3873 - val_acc: 0.8383
# Epoch 5/25
#  - 186s - loss: 0.2751 - acc: 0.8796 - val_loss: 0.3792 - val_acc: 0.8495
# Epoch 6/25
#  - 186s - loss: 0.2428 - acc: 0.8954 - val_loss: 0.3877 - val_acc: 0.8512

# %%
print (np.mean(val_loss_result))
res = (pred_results[0] + pred_results[1] + pred_results[2] +
     pred_results[3] + pred_results[4]) / 5
print (np.mean(res))
# Out:
# 0.3704194028800893
# 0.19354118

# %%
train_pred_results
# Out:
# [array([0.0132224], dtype=float32),
#  array([0.9482949], dtype=float32),
#  array([0.00555854], dtype=float32),
#  array([0.19725102], dtype=float32),
#  array([0.00360902], dtype=float32),
#  array([0.00414053], dtype=float32),
#  array([0.5190295], dtype=float32),
#  array([0.00308324], dtype=float32),
#  array([0.02992265], dtype=float32),
#  array([0.17340365], dtype=float32),
#  array([0.01715632], dtype=float32),
#  array([0.03025903], dtype=float32),
#  array([0.18091947], dtype=float32),
#  array([0.2528809], dtype=float32),
#  array([0.00127765], dtype=float32),
#  array([0.01658015], dtype=float32),
#  array([0.06136921], dtype=float32),
#  array([0.00184594], dtype=float32),
#  array([0.0002222], dtype=float32),
#  array([0.00304958], dtype=float32),
#  array([0.00149684], dtype=float32),
#  array([0.01854541], dtype=float32),
#  array([0.00168638], dtype=float32),
#  array([0.01097297], dtype=float32),
#  array([0.93930805], dtype=float32),
#  array([0.5494567], dtype=float32),
#  array([0.02942273], dtype=float32),
#  array([0.17015637], dtype=float32),
#  array([0.05021987], dtype=float32),
#  array([0.03809543], dtype=float32),
#  array([0.95271814], dtype=float32),
#  array([0.29324123], dtype=float32),
#  array([0.7389057], dtype=float32),
#  array([0.04512287], dtype=float32),
#  array([0.00898841], dtype=float32),
#  array([0.00984151], dtype=float32),
#  array([0.00291493], dtype=float32),
#  array([0.6854862], dtype=float32),
#  array([0.00192179], dtype=float32),
#  array([0.00133972], dtype=float32),
#  array([0.01193589], dtype=float32),
#  array([0.3457173], dtype=float32),
#  array([0.00102224], dtype=float32),
#  array([0.00379356], dtype=float32),
#  array([0.9320489], dtype=float32),
#  array([0.00814432], dtype=float32),
#  array([0.82958364], dtype=float32),
#  array([0.06352053], dtype=float32),
#  array([0.08530802], dtype=float32),
#  array([0.00205655], dtype=float32),
#  array([0.0671917], dtype=float32),
#  array([0.00013127], dtype=float32),
#  array([0.36221686], dtype=float32),
#  array([0.00283145], dtype=float32),
#  array([0.8615432], dtype=float32),
#  array([0.08990716], dtype=float32),
#  array([0.00174686], dtype=float32),
#  array([0.01284198], dtype=float32),
#  array([0.00580586], dtype=float32),
#  array([0.00058363], dtype=float32),
#  array([0.04029437], dtype=float32),
#  array([0.05406933], dtype=float32),
#  array([0.01072685], dtype=float32),
#  array([0.0384387], dtype=float32),
#  array([0.67573905], dtype=float32),
#  array([0.04715621], dtype=float32),
#  array([0.69902855], dtype=float32),
#  array([0.00030725], dtype=float32),
#  array([0.2968484], dtype=float32),
#  array([0.96714216], dtype=float32),
#  array([0.02720954], dtype=float32),
#  array([0.04352392], dtype=float32),
#  array([0.96824247], dtype=float32),
#  array([0.00141624], dtype=float32),
#  array([0.0006974], dtype=float32),
#  array([0.00011543], dtype=float32),
#  array([0.61380154], dtype=float32),
#  array([0.00829085], dtype=float32),
#  array([0.00521553], dtype=float32),
#  array([0.00513977], dtype=float32),
#  array([0.00311141], dtype=float32),
#  array([0.80140144], dtype=float32),
#  array([0.16504896], dtype=float32),
#  array([0.01903414], dtype=float32),
#  array([0.00349679], dtype=float32),
#  array([0.01013646], dtype=float32),
#  array([0.03140088], dtype=float32),
#  array([0.08257639], dtype=float32),
#  array([0.03450718], dtype=float32),
#  array([0.04146513], dtype=float32),
#  array([0.02026239], dtype=float32),
#  array([0.1993144], dtype=float32),
#  array([0.15458235], dtype=float32),
#  array([0.41312057], dtype=float32),
#  array([0.07397079], dtype=float32),
#  array([0.00025746], dtype=float32),
#  array([0.0065541], dtype=float32),
#  array([0.84629166], dtype=float32),
#  array([0.00167548], dtype=float32),
#  array([0.7809588], dtype=float32),
#  array([0.21003668], dtype=float32),
#  array([0.0100668], dtype=float32),
#  array([0.0018815], dtype=float32),
#  array([0.51365], dtype=float32),
#  array([0.26850328], dtype=float32),
#  array([0.94732445], dtype=float32),
#  array([0.052465], dtype=float32),
#  array([0.6085029], dtype=float32),
#  array([0.11889937], dtype=float32),
#  array([0.00817467], dtype=float32),
#  array([0.00098602], dtype=float32),
#  array([0.00414679], dtype=float32),
#  array([0.18448286], dtype=float32),
#  array([0.00050076], dtype=float32),
#  array([0.9903522], dtype=float32),
#  array([0.55024785], dtype=float32),
#  array([0.36838713], dtype=float32),
#  array([0.81022257], dtype=float32),
#  array([0.00139012], dtype=float32),
#  array([0.03935866], dtype=float32),
#  array([0.08689324], dtype=float32),
#  array([0.00662267], dtype=float32),
#  array([0.25926384], dtype=float32),
#  array([0.02369474], dtype=float32),
#  array([0.57155603], dtype=float32),
#  array([0.01397737], dtype=float32),
#  array([0.8911376], dtype=float32),
#  array([0.9478997], dtype=float32),
#  array([0.00740529], dtype=float32),
#  array([0.90157], dtype=float32),
#  array([0.00065059], dtype=float32),
#  array([0.00547955], dtype=float32),
#  array([0.04927438], dtype=float32),
#  array([0.01543311], dtype=float32),
#  array([0.01918145], dtype=float32),
#  array([0.01549812], dtype=float32),
#  array([0.67408127], dtype=float32),
#  array([0.2943874], dtype=float32),
#  array([0.9878324], dtype=float32),
#  array([0.15294518], dtype=float32),
#  array([0.20339994], dtype=float32),
#  array([0.1755349], dtype=float32),
#  array([0.00013928], dtype=float32),
#  array([0.3198869], dtype=float32),
#  array([0.6927022], dtype=float32),
#  array([0.9863435], dtype=float32),
#  array([0.03324589], dtype=float32),
#  array([0.67575306], dtype=float32),
#  array([0.48418042], dtype=float32),
#  array([0.00153515], dtype=float32),
#  array([0.01421928], dtype=float32),
#  array([0.0005874], dtype=float32),
#  array([0.01323834], dtype=float32),
#  array([0.00578025], dtype=float32),
#  array([0.03699366], dtype=float32),
#  array([0.20749718], dtype=float32),
#  array([0.01825511], dtype=float32),
#  array([0.0206881], dtype=float32),
#  array([0.8212475], dtype=float32),
#  array([0.07232074], dtype=float32),
#  array([0.01204307], dtype=float32),
#  array([0.7599197], dtype=float32),
#  array([0.05017075], dtype=float32),
#  array([0.91697985], dtype=float32),
#  array([0.00772288], dtype=float32),
#  array([0.00063422], dtype=float32),
#  array([0.04450745], dtype=float32),
#  array([0.6801824], dtype=float32),
#  array([0.00105317], dtype=float32),
#  array([0.97228223], dtype=float32),
#  array([0.00738957], dtype=float32),
#  array([0.00012575], dtype=float32),
#  array([0.8115557], dtype=float32),
#  array([0.00083044], dtype=float32),
#  array([0.92339504], dtype=float32),
#  array([0.00039702], dtype=float32),
#  array([0.01488528], dtype=float32),
#  array([0.09108538], dtype=float32),
#  array([0.00095154], dtype=float32),
#  array([0.00510773], dtype=float32),
#  array([0.000209], dtype=float32),
#  array([0.01227967], dtype=float32),
#  array([0.82443535], dtype=float32),
#  array([0.00058478], dtype=float32),
#  array([0.00167209], dtype=float32),
#  array([0.01600535], dtype=float32),
#  array([0.6793074], dtype=float32),
#  array([0.8229066], dtype=float32),
#  array([0.00014734], dtype=float32),
#  array([0.0011076], dtype=float32),
#  array([0.05269737], dtype=float32),
#  array([0.02009704], dtype=float32),
#  array([0.01265818], dtype=float32),
#  array([0.01384453], dtype=float32),
#  array([0.00029197], dtype=float32),
#  array([0.09030491], dtype=float32),
#  array([0.00995517], dtype=float32),
#  array([0.7892318], dtype=float32),
#  array([0.0024669], dtype=float32),
#  array([0.00042534], dtype=float32),
#  array([0.19441848], dtype=float32),
#  array([0.00241787], dtype=float32),
#  array([0.60212207], dtype=float32),
#  array([0.3497117], dtype=float32),
#  array([0.00024524], dtype=float32),
#  array([0.46513054], dtype=float32),
#  array([0.064541], dtype=float32),
#  array([0.755874], dtype=float32),
#  array([0.03058209], dtype=float32),
#  array([0.00981053], dtype=float32),
#  array([0.00959161], dtype=float32),
#  array([0.3535235], dtype=float32),
#  array([0.12534261], dtype=float32),
#  array([0.23117463], dtype=float32),
#  array([0.00150234], dtype=float32),
#  array([0.38921437], dtype=float32),
#  array([0.03741048], dtype=float32),
#  array([0.00530726], dtype=float32),
#  array([0.9745963], dtype=float32),
#  array([0.70730907], dtype=float32),
#  array([0.04308829], dtype=float32),
#  array([0.00043122], dtype=float32),
#  array([0.8758241], dtype=float32),
#  array([0.00120659], dtype=float32),
#  array([0.15562351], dtype=float32),
#  array([0.48373988], dtype=float32),
#  array([0.02937532], dtype=float32),
#  array([0.00080669], dtype=float32),
#  array([0.20759651], dtype=float32),
#  array([0.00111473], dtype=float32),
#  array([0.02639906], dtype=float32),
#  array([0.03030543], dtype=float32),
#  array([0.00045896], dtype=float32),
#  array([0.00399032], dtype=float32),
#  array([0.11265974], dtype=float32),
#  array([0.04517759], dtype=float32),
#  array([0.66299224], dtype=float32),
#  array([0.08328985], dtype=float32),
#  array([0.9144342], dtype=float32),
#  array([0.00721043], dtype=float32),
#  array([0.00025811], dtype=float32),
#  array([0.08718111], dtype=float32),
#  array([0.00952203], dtype=float32),
#  array([0.8543603], dtype=float32),
#  array([0.6349784], dtype=float32),
#  array([0.5290586], dtype=float32),
#  array([0.21820322], dtype=float32),
#  array([0.73609036], dtype=float32),
#  array([0.18949206], dtype=float32),
#  array([0.1322086], dtype=float32),
#  array([0.54250634], dtype=float32),
#  array([0.23321915], dtype=float32),
#  array([0.99593097], dtype=float32),
#  array([0.00021747], dtype=float32),
#  array([0.19698772], dtype=float32),
#  array([0.06260498], dtype=float32),
#  array([0.00902686], dtype=float32),
#  array([0.01248373], dtype=float32),
#  array([0.9163247], dtype=float32),
#  array([0.0105415], dtype=float32),
#  array([0.2916042], dtype=float32),
#  array([0.39967293], dtype=float32),
#  array([0.01838233], dtype=float32),
#  array([0.16761032], dtype=float32),
#  array([0.11706952], dtype=float32),
#  array([0.00834018], dtype=float32),
#  array([0.00114764], dtype=float32),
#  array([0.00235525], dtype=float32),
#  array([0.02520443], dtype=float32),
#  array([0.00010715], dtype=float32),
#  array([0.00262926], dtype=float32),
#  array([0.00353538], dtype=float32),
#  array([0.00554452], dtype=float32),
#  array([0.38574073], dtype=float32),
#  array([0.9046891], dtype=float32),
#  array([0.21349765], dtype=float32),
#  array([0.00446358], dtype=float32),
#  array([0.05082626], dtype=float32),
#  array([0.00361819], dtype=float32),
#  array([0.71991324], dtype=float32),
#  array([0.00128297], dtype=float32),
#  array([0.21233125], dtype=float32),
#  array([0.00498815], dtype=float32),
#  array([0.9839902], dtype=float32),
#  array([0.00026624], dtype=float32),
#  array([0.01274579], dtype=float32),
#  array([0.3345135], dtype=float32),
#  array([0.89445513], dtype=float32),
#  array([0.0447645], dtype=float32),
#  array([0.23360816], dtype=float32),
#  array([0.00341182], dtype=float32),
#  array([0.99642986], dtype=float32),
#  array([0.5934458], dtype=float32),
#  array([0.02696628], dtype=float32),
#  array([0.44785342], dtype=float32),
#  array([0.5751456], dtype=float32),
#  array([0.00344534], dtype=float32),
#  array([0.03634692], dtype=float32),
#  array([0.01733273], dtype=float32),
#  array([0.13484707], dtype=float32),
#  array([0.00397416], dtype=float32),
#  array([0.01126244], dtype=float32),
#  array([0.02789834], dtype=float32),
#  array([0.69896376], dtype=float32),
#  array([0.00915512], dtype=float32),
#  array([0.00480027], dtype=float32),
#  array([0.17171477], dtype=float32),
#  array([0.00070711], dtype=float32),
#  array([0.01652512], dtype=float32),
#  array([0.00940348], dtype=float32),
#  array([0.00010536], dtype=float32),
#  array([0.3863615], dtype=float32),
#  array([0.3482622], dtype=float32),
#  array([0.27313653], dtype=float32),
#  array([0.23712377], dtype=float32),
#  array([0.0151752], dtype=float32),
#  array([0.0081861], dtype=float32),
#  array([0.00323592], dtype=float32),
#  array([0.40904927], dtype=float32),
#  array([0.00273245], dtype=float32),
#  array([0.01382537], dtype=float32),
#  array([0.00091214], dtype=float32),
#  array([0.03475641], dtype=float32),
#  array([0.84149516], dtype=float32),
#  array([0.00155174], dtype=float32),
#  array([0.84919894], dtype=float32),
#  array([0.5130952], dtype=float32),
#  array([0.00125821], dtype=float32),
#  array([0.00878565], dtype=float32),
#  array([0.09658147], dtype=float32),
#  array([0.00128646], dtype=float32),
#  array([0.37024775], dtype=float32),
#  array([0.02761242], dtype=float32),
#  array([0.4973919], dtype=float32),
#  array([0.00330941], dtype=float32),
#  array([0.83596367], dtype=float32),
#  array([0.0129595], dtype=float32),
#  array([0.10215939], dtype=float32),
#  array([0.71509135], dtype=float32),
#  array([0.00208228], dtype=float32),
#  array([0.01369756], dtype=float32),
#  array([0.20418017], dtype=float32),
#  array([0.00795318], dtype=float32),
#  array([0.15468843], dtype=float32),
#  array([0.0039301], dtype=float32),
#  array([0.72903705], dtype=float32),
#  array([0.88219476], dtype=float32),
#  array([0.0567574], dtype=float32),
#  array([0.8980901], dtype=float32),
#  array([0.9319735], dtype=float32),
#  array([0.00320842], dtype=float32),
#  array([0.00064163], dtype=float32),
#  array([0.64854974], dtype=float32),
#  array([6.6047294e-05], dtype=float32),
#  array([0.0696899], dtype=float32),
#  array([0.5419575], dtype=float32),
#  array([0.00064268], dtype=float32),
#  array([0.01228363], dtype=float32),
#  array([0.00037301], dtype=float32),
#  array([0.5414977], dtype=float32),
#  array([0.00177741], dtype=float32),
#  array([0.1628461], dtype=float32),
#  array([0.00452962], dtype=float32),
#  array([0.5907436], dtype=float32),
#  array([0.5044831], dtype=float32),
#  array([0.01043174], dtype=float32),
#  array([0.00236176], dtype=float32),
#  array([0.00561083], dtype=float32),
#  array([0.44944718], dtype=float32),
#  array([0.52085406], dtype=float32),
#  array([0.06671793], dtype=float32),
#  array([0.04267757], dtype=float32),
#  array([0.7197571], dtype=float32),
#  array([0.20522231], dtype=float32),
#  array([0.04666129], dtype=float32),
#  array([0.04923059], dtype=float32),
#  array([0.7652488], dtype=float32),
#  array([0.00196051], dtype=float32),
#  array([0.00262029], dtype=float32),
#  array([0.02094112], dtype=float32),
#  array([0.6096764], dtype=float32),
#  array([0.00052402], dtype=float32),
#  array([0.063581], dtype=float32),
#  array([0.01321934], dtype=float32),
#  array([0.00307393], dtype=float32),
#  array([0.39007723], dtype=float32),
#  array([0.01132414], dtype=float32),
#  array([0.26817006], dtype=float32),
#  array([0.00052095], dtype=float32),
#  array([0.00220826], dtype=float32),
#  array([0.86820394], dtype=float32),
#  array([0.02502617], dtype=float32),
#  array([0.00362438], dtype=float32),
#  array([0.02871769], dtype=float32),
#  array([0.9722214], dtype=float32),
#  array([0.3529118], dtype=float32),
#  array([0.9782482], dtype=float32),
#  array([0.300727], dtype=float32),
#  array([1.653319e-05], dtype=float32),
#  array([0.00606797], dtype=float32),
#  array([0.01626924], dtype=float32),
#  array([0.00193195], dtype=float32),
#  array([0.00123527], dtype=float32),
#  array([0.00106614], dtype=float32),
#  array([0.08622716], dtype=float32),
#  array([0.01143536], dtype=float32),
#  array([0.00104353], dtype=float32),
#  array([0.98544544], dtype=float32),
#  array([0.00147284], dtype=float32),
#  array([0.23814219], dtype=float32),
#  array([0.00235399], dtype=float32),
#  array([0.00158309], dtype=float32),
#  array([0.00139136], dtype=float32),
#  array([0.01456687], dtype=float32),
#  array([0.00014791], dtype=float32),
#  array([0.26912987], dtype=float32),
#  array([0.46734133], dtype=float32),
#  array([0.0057375], dtype=float32),
#  array([0.30936974], dtype=float32),
#  array([0.9846489], dtype=float32),
#  array([0.0195735], dtype=float32),
#  array([0.00594464], dtype=float32),
#  array([0.00496717], dtype=float32),
#  array([0.01380504], dtype=float32),
#  array([0.5829764], dtype=float32),
#  array([0.38361907], dtype=float32),
#  array([0.00017251], dtype=float32),
#  array([0.01015764], dtype=float32),
#  array([0.0040815], dtype=float32),
#  array([0.7175932], dtype=float32),
#  array([0.7381363], dtype=float32),
#  array([0.887547], dtype=float32),
#  array([0.07905933], dtype=float32),
#  array([0.02073308], dtype=float32),
#  array([5.634873e-05], dtype=float32),
#  array([0.07121476], dtype=float32),
#  array([0.02636941], dtype=float32),
#  array([0.01446457], dtype=float32),
#  array([0.00029982], dtype=float32),
#  array([0.00814266], dtype=float32),
#  array([0.00565203], dtype=float32),
#  array([0.20572698], dtype=float32),
#  array([0.00056173], dtype=float32),
#  array([0.03622664], dtype=float32),
#  array([0.08356125], dtype=float32),
#  array([0.7241341], dtype=float32),
#  array([0.32977664], dtype=float32),
#  array([0.00170298], dtype=float32),
#  array([0.7199017], dtype=float32),
#  array([0.00060419], dtype=float32),
#  array([0.12106498], dtype=float32),
#  array([0.03123203], dtype=float32),
#  array([0.00046138], dtype=float32),
#  array([0.14422262], dtype=float32),
#  array([0.87191373], dtype=float32),
#  array([0.02608888], dtype=float32),
#  array([0.00158679], dtype=float32),
#  array([0.03067648], dtype=float32),
#  array([0.47780696], dtype=float32),
#  array([0.0007781], dtype=float32),
#  array([0.01090316], dtype=float32),
#  array([0.98137385], dtype=float32),
#  array([0.00210605], dtype=float32),
#  array([0.8190696], dtype=float32),
#  array([0.900642], dtype=float32),
#  array([0.00357929], dtype=float32),
#  array([0.87093943], dtype=float32),
#  array([0.00408256], dtype=float32),
#  array([0.00376783], dtype=float32),
#  array([0.00247415], dtype=float32),
#  array([0.00194186], dtype=float32),
#  array([0.00830828], dtype=float32),
#  array([0.01718071], dtype=float32),
#  array([0.08016457], dtype=float32),
#  array([0.02245752], dtype=float32),
#  array([0.00961827], dtype=float32),
#  array([0.01049957], dtype=float32),
#  array([0.00088081], dtype=float32),
#  array([0.7554171], dtype=float32),
#  array([0.01603398], dtype=float32),
#  array([0.07003909], dtype=float32),
#  array([0.00624527], dtype=float32),
#  array([0.9093485], dtype=float32),
#  array([0.73058414], dtype=float32),
#  array([0.00235439], dtype=float32),
#  array([0.00297901], dtype=float32),
#  array([0.05816219], dtype=float32),
#  array([0.01261515], dtype=float32),
#  array([0.00030562], dtype=float32),
#  array([0.00405415], dtype=float32),
#  array([0.05641221], dtype=float32),
#  array([0.35368103], dtype=float32),
#  array([0.00034492], dtype=float32),
#  array([0.00061064], dtype=float32),
#  array([0.00205519], dtype=float32),
#  array([0.00047623], dtype=float32),
#  array([0.00218874], dtype=float32),
#  array([0.11435609], dtype=float32),
#  array([0.05828094], dtype=float32),
#  array([0.00924159], dtype=float32),
#  array([0.00392521], dtype=float32),
#  array([0.4069908], dtype=float32),
#  array([0.00384485], dtype=float32),
#  array([0.01027011], dtype=float32),
#  array([0.0095612], dtype=float32),
#  array([0.9855547], dtype=float32),
#  array([0.86781764], dtype=float32),
#  array([0.03084064], dtype=float32),
#  array([0.5026624], dtype=float32),
#  array([0.00414292], dtype=float32),
#  array([0.00184232], dtype=float32),
#  array([0.00185884], dtype=float32),
#  array([0.01989095], dtype=float32),
#  array([0.7892766], dtype=float32),
#  array([0.04951603], dtype=float32),
#  array([0.00019895], dtype=float32),
#  array([0.00062351], dtype=float32),
#  array([0.01236166], dtype=float32),
#  array([0.95801926], dtype=float32),
#  array([0.00382867], dtype=float32),
#  array([0.00014308], dtype=float32),
#  array([0.00134839], dtype=float32),
#  array([0.00775257], dtype=float32),
#  array([0.7961276], dtype=float32),
#  array([0.0092466], dtype=float32),
#  array([0.45270973], dtype=float32),
#  array([0.00067777], dtype=float32),
#  array([0.20462854], dtype=float32),
#  array([0.01089811], dtype=float32),
#  array([0.00514474], dtype=float32),
#  array([0.7796107], dtype=float32),
#  array([0.6764269], dtype=float32),
#  array([0.00047968], dtype=float32),
#  array([0.00131194], dtype=float32),
#  array([0.00126052], dtype=float32),
#  array([0.01346285], dtype=float32),
#  array([0.04087488], dtype=float32),
#  array([0.00033807], dtype=float32),
#  array([0.00061552], dtype=float32),
#  array([0.00069751], dtype=float32),
#  array([0.02681942], dtype=float32),
#  array([0.94142723], dtype=float32),
#  array([0.01754294], dtype=float32),
#  array([0.02790125], dtype=float32),
#  array([0.00345895], dtype=float32),
#  array([0.26144037], dtype=float32),
#  array([0.2695517], dtype=float32),
#  array([0.01350961], dtype=float32),
#  array([0.7612768], dtype=float32),
#  array([0.04664677], dtype=float32),
#  array([0.00769255], dtype=float32),
#  array([0.06087116], dtype=float32),
#  array([0.9821035], dtype=float32),
#  array([0.01543208], dtype=float32),
#  array([0.00410029], dtype=float32),
#  array([0.01541071], dtype=float32),
#  array([0.09855451], dtype=float32),
#  array([0.02457806], dtype=float32),
#  array([0.00016419], dtype=float32),
#  array([0.2328399], dtype=float32),
#  array([0.01863879], dtype=float32),
#  array([0.05054384], dtype=float32),
#  array([0.00057623], dtype=float32),
#  array([0.00126048], dtype=float32),
#  array([0.00585687], dtype=float32),
#  array([0.00233173], dtype=float32),
#  array([0.9150436], dtype=float32),
#  array([0.97589433], dtype=float32),
#  array([0.00010942], dtype=float32),
#  array([0.02318226], dtype=float32),
#  array([0.06468878], dtype=float32),
#  array([0.00138152], dtype=float32),
#  array([0.9939394], dtype=float32),
#  array([0.01002351], dtype=float32),
#  array([0.02623299], dtype=float32),
#  array([5.818941e-05], dtype=float32),
#  array([0.01623116], dtype=float32),
#  array([0.00047417], dtype=float32),
#  array([0.00243922], dtype=float32),
#  array([6.989496e-05], dtype=float32),
#  array([5.497896e-05], dtype=float32),
#  array([0.0027013], dtype=float32),
#  array([0.04920735], dtype=float32),
#  array([0.00100982], dtype=float32),
#  array([0.25458315], dtype=float32),
#  array([0.00840312], dtype=float32),
#  array([0.94674486], dtype=float32),
#  array([0.04176749], dtype=float32),
#  array([0.01634878], dtype=float32),
#  array([0.00252487], dtype=float32),
#  array([0.00094602], dtype=float32),
#  array([0.7927077], dtype=float32),
#  array([0.01582174], dtype=float32),
#  array([0.08535536], dtype=float32),
#  array([0.03953086], dtype=float32),
#  array([0.95683783], dtype=float32),
#  array([0.00948602], dtype=float32),
#  array([0.97919697], dtype=float32),
#  array([0.19793874], dtype=float32),
#  array([0.8553397], dtype=float32),
#  array([0.0076037], dtype=float32),
#  array([0.00236951], dtype=float32),
#  array([0.57204676], dtype=float32),
#  array([0.00215848], dtype=float32),
#  array([0.13983963], dtype=float32),
#  array([0.880021], dtype=float32),
#  array([0.8371653], dtype=float32),
#  array([0.01146823], dtype=float32),
#  array([0.11508262], dtype=float32),
#  array([0.5181959], dtype=float32),
#  array([0.37237465], dtype=float32),
#  array([0.35388884], dtype=float32),
#  array([0.6771793], dtype=float32),
#  array([0.10201925], dtype=float32),
#  array([0.03139396], dtype=float32),
#  array([0.83929807], dtype=float32),
#  array([0.01795989], dtype=float32),
#  array([0.00092182], dtype=float32),
#  array([0.84448457], dtype=float32),
#  array([0.80282086], dtype=float32),
#  array([0.47351637], dtype=float32),
#  array([0.80852664], dtype=float32),
#  array([0.02368481], dtype=float32),
#  array([0.00081016], dtype=float32),
#  array([0.99859864], dtype=float32),
#  array([0.15356052], dtype=float32),
#  array([0.8100609], dtype=float32),
#  array([0.530203], dtype=float32),
#  array([0.02194345], dtype=float32),
#  array([0.9674924], dtype=float32),
#  array([0.00118228], dtype=float32),
#  array([0.07616811], dtype=float32),
#  array([0.01722066], dtype=float32),
#  array([0.0310187], dtype=float32),
#  array([0.52706826], dtype=float32),
#  array([0.2780457], dtype=float32),
#  array([0.00081891], dtype=float32),
#  array([0.00109278], dtype=float32),
#  array([0.00179056], dtype=float32),
#  array([0.5333399], dtype=float32),
#  array([0.75465626], dtype=float32),
#  array([0.75609636], dtype=float32),
#  array([0.00129979], dtype=float32),
#  array([0.00303283], dtype=float32),
#  array([0.00347477], dtype=float32),
#  array([0.00276808], dtype=float32),
#  array([0.05217425], dtype=float32),
#  array([0.00047088], dtype=float32),
#  array([0.00619428], dtype=float32),
#  array([0.01260855], dtype=float32),
#  array([0.64307666], dtype=float32),
#  array([0.23836246], dtype=float32),
#  array([0.7250115], dtype=float32),
#  array([0.7165278], dtype=float32),
#  array([0.43083945], dtype=float32),
#  array([0.86298394], dtype=float32),
#  array([0.02966863], dtype=float32),
#  array([0.7257982], dtype=float32),
#  array([0.05558773], dtype=float32),
#  array([0.01036697], dtype=float32),
#  array([0.697558], dtype=float32),
#  array([0.00013385], dtype=float32),
#  array([0.001024], dtype=float32),
#  array([0.33873445], dtype=float32),
#  array([0.2689861], dtype=float32),
#  array([0.06467186], dtype=float32),
#  array([0.00315336], dtype=float32),
#  array([0.01730279], dtype=float32),
#  array([0.00830354], dtype=float32),
#  array([0.00578536], dtype=float32),
#  array([0.00581471], dtype=float32),
#  array([0.0031567], dtype=float32),
#  array([0.5798651], dtype=float32),
#  array([0.02571752], dtype=float32),
#  array([0.00173198], dtype=float32),
#  array([0.04522452], dtype=float32),
#  array([0.33192667], dtype=float32),
#  array([0.02080391], dtype=float32),
#  array([0.01622977], dtype=float32),
#  array([0.00046891], dtype=float32),
#  array([0.00304117], dtype=float32),
#  array([0.00165179], dtype=float32),
#  array([0.900529], dtype=float32),
#  array([0.00405144], dtype=float32),
#  array([0.09229306], dtype=float32),
#  array([0.04825765], dtype=float32),
#  array([0.9841649], dtype=float32),
#  array([0.44891334], dtype=float32),
#  array([0.80662715], dtype=float32),
#  array([0.06769785], dtype=float32),
#  array([0.00432944], dtype=float32),
#  array([0.08904834], dtype=float32),
#  array([0.829208], dtype=float32),
#  array([0.32302305], dtype=float32),
#  array([0.3513683], dtype=float32),
#  array([0.01259209], dtype=float32),
#  array([0.0238911], dtype=float32),
#  array([0.58578527], dtype=float32),
#  array([0.24997431], dtype=float32),
#  array([0.9991172], dtype=float32),
#  array([0.01670521], dtype=float32),
#  array([0.01314721], dtype=float32),
#  array([0.98438627], dtype=float32),
#  array([0.00318495], dtype=float32),
#  array([0.02933648], dtype=float32),
#  array([0.00291459], dtype=float32),
#  array([0.33144316], dtype=float32),
#  array([0.00442631], dtype=float32),
#  array([0.8054148], dtype=float32),
#  array([0.00285401], dtype=float32),
#  array([0.01301979], dtype=float32),
#  array([0.0163687], dtype=float32),
#  array([0.00511547], dtype=float32),
#  array([0.02224029], dtype=float32),
#  array([0.36754373], dtype=float32),
#  array([0.29454267], dtype=float32),
#  array([0.02030127], dtype=float32),
#  array([0.00628793], dtype=float32),
#  array([0.00794049], dtype=float32),
#  array([0.16639178], dtype=float32),
#  array([0.00325629], dtype=float32),
#  array([0.0147678], dtype=float32),
#  array([0.7100307], dtype=float32),
#  array([0.03958847], dtype=float32),
#  array([0.00193677], dtype=float32),
#  array([0.02268157], dtype=float32),
#  array([0.0001732], dtype=float32),
#  array([0.0132756], dtype=float32),
#  array([0.00253644], dtype=float32),
#  array([0.00055601], dtype=float32),
#  array([0.02165698], dtype=float32),
#  array([0.00630548], dtype=float32),
#  array([0.8900869], dtype=float32),
#  array([2.2945356e-05], dtype=float32),
#  array([0.00418564], dtype=float32),
#  array([0.00479401], dtype=float32),
#  array([0.24419256], dtype=float32),
#  array([0.00187837], dtype=float32),
#  array([0.9368002], dtype=float32),
#  array([0.04370387], dtype=float32),
#  array([0.02808412], dtype=float32),
#  array([0.00164088], dtype=float32),
#  array([0.6137318], dtype=float32),
#  array([0.00130501], dtype=float32),
#  array([0.01242045], dtype=float32),
#  array([0.9480573], dtype=float32),
#  array([0.0013698], dtype=float32),
#  array([0.0771983], dtype=float32),
#  array([0.70663697], dtype=float32),
#  array([0.00325853], dtype=float32),
#  array([0.09906207], dtype=float32),
#  array([0.02119179], dtype=float32),
#  array([0.01486394], dtype=float32),
#  array([0.30373368], dtype=float32),
#  array([0.6444843], dtype=float32),
#  array([0.32606295], dtype=float32),
#  array([0.05518347], dtype=float32),
#  array([0.00233996], dtype=float32),
#  array([0.01063048], dtype=float32),
#  array([0.9584879], dtype=float32),
#  array([0.01685899], dtype=float32),
#  array([0.9949491], dtype=float32),
#  array([0.86263615], dtype=float32),
#  array([0.4901907], dtype=float32),
#  array([0.01326915], dtype=float32),
#  array([0.00348097], dtype=float32),
#  array([0.09968338], dtype=float32),
#  array([0.00016498], dtype=float32),
#  array([0.00124387], dtype=float32),
#  array([0.9734267], dtype=float32),
#  array([0.00406907], dtype=float32),
#  array([0.00141403], dtype=float32),
#  array([0.00309203], dtype=float32),
#  array([0.00038634], dtype=float32),
#  array([0.00132486], dtype=float32),
#  array([0.15817632], dtype=float32),
#  array([0.00737975], dtype=float32),
#  array([0.03745646], dtype=float32),
#  array([0.01002258], dtype=float32),
#  array([0.00289121], dtype=float32),
#  array([0.0081757], dtype=float32),
#  array([0.7589631], dtype=float32),
#  array([0.9976241], dtype=float32),
#  array([0.00042803], dtype=float32),
#  array([0.00037969], dtype=float32),
#  array([0.10555521], dtype=float32),
#  array([0.00608994], dtype=float32),
#  array([0.36424556], dtype=float32),
#  array([0.00721762], dtype=float32),
#  array([0.05114461], dtype=float32),
#  array([0.9963658], dtype=float32),
#  array([0.00123977], dtype=float32),
#  array([0.0001512], dtype=float32),
#  array([0.16616817], dtype=float32),
#  array([0.00029387], dtype=float32),
#  array([0.0449716], dtype=float32),
#  array([0.01179821], dtype=float32),
#  array([0.01543849], dtype=float32),
#  array([0.2177042], dtype=float32),
#  array([0.07003058], dtype=float32),
#  array([0.19107659], dtype=float32),
#  array([0.8578724], dtype=float32),
#  array([0.10095239], dtype=float32),
#  array([0.903573], dtype=float32),
#  array([0.00174766], dtype=float32),
#  array([0.6841738], dtype=float32),
#  array([0.00207996], dtype=float32),
#  array([0.01191737], dtype=float32),
#  array([0.03240374], dtype=float32),
#  array([0.6438963], dtype=float32),
#  array([0.00435283], dtype=float32),
#  array([0.00124284], dtype=float32),
#  array([0.00130319], dtype=float32),
#  array([0.01786428], dtype=float32),
#  array([0.02304309], dtype=float32),
#  array([0.45871103], dtype=float32),
#  array([0.8201692], dtype=float32),
#  array([0.5999235], dtype=float32),
#  array([0.18259616], dtype=float32),
#  array([0.84085023], dtype=float32),
#  array([0.38112226], dtype=float32),
#  array([0.00807122], dtype=float32),
#  array([0.0365211], dtype=float32),
#  array([0.72980714], dtype=float32),
#  array([0.98901284], dtype=float32),
#  array([0.8020591], dtype=float32),
#  array([3.3786197e-05], dtype=float32),
#  array([0.7844101], dtype=float32),
#  array([0.02682756], dtype=float32),
#  array([0.04575222], dtype=float32),
#  array([0.00163074], dtype=float32),
#  array([0.02702018], dtype=float32),
#  array([0.0023723], dtype=float32),
#  array([0.7662763], dtype=float32),
#  array([0.78429973], dtype=float32),
#  array([0.59365326], dtype=float32),
#  array([0.98785746], dtype=float32),
#  array([0.0007063], dtype=float32),
#  array([0.00045017], dtype=float32),
#  array([0.00065206], dtype=float32),
#  array([0.01210934], dtype=float32),
#  array([0.00051772], dtype=float32),
#  array([0.51688015], dtype=float32),
#  array([0.00199286], dtype=float32),
#  array([0.8290246], dtype=float32),
#  array([0.04341243], dtype=float32),
#  array([0.00665506], dtype=float32),
#  array([0.00161439], dtype=float32),
#  array([0.01437344], dtype=float32),
#  array([0.12080599], dtype=float32),
#  array([0.00055083], dtype=float32),
#  array([0.00439719], dtype=float32),
#  array([0.23691937], dtype=float32),
#  array([0.00059112], dtype=float32),
#  array([0.70382077], dtype=float32),
#  array([0.6570607], dtype=float32),
#  array([0.00895351], dtype=float32),
#  array([0.00894523], dtype=float32),
#  array([0.00010577], dtype=float32),
#  array([0.9668521], dtype=float32),
#  array([0.14085093], dtype=float32),
#  array([0.1341653], dtype=float32),
#  array([0.72004646], dtype=float32),
#  array([0.25785512], dtype=float32),
#  array([0.9943915], dtype=float32),
#  array([0.736278], dtype=float32),
#  array([0.04883289], dtype=float32),
#  array([0.05143284], dtype=float32),
#  array([0.00121682], dtype=float32),
#  array([0.03086742], dtype=float32),
#  array([0.93861437], dtype=float32),
#  array([0.05153891], dtype=float32),
#  array([0.00169625], dtype=float32),
#  array([0.00898919], dtype=float32),
#  array([0.01293158], dtype=float32),
#  array([0.70080245], dtype=float32),
#  array([0.07538848], dtype=float32),
#  array([0.9495193], dtype=float32),
#  array([0.01735014], dtype=float32),
#  array([0.00513935], dtype=float32),
#  array([0.02234867], dtype=float32),
#  array([0.4838789], dtype=float32),
#  array([0.04782757], dtype=float32),
#  array([0.00035176], dtype=float32),
#  array([0.00161868], dtype=float32),
#  array([0.16666839], dtype=float32),
#  array([0.8617154], dtype=float32),
#  array([0.40721247], dtype=float32),
#  array([0.16455376], dtype=float32),
#  array([0.11121704], dtype=float32),
#  array([0.00493978], dtype=float32),
#  array([0.9082584], dtype=float32),
#  array([0.0070795], dtype=float32),
#  array([0.2507608], dtype=float32),
#  array([0.11467765], dtype=float32),
#  array([0.0011686], dtype=float32),
#  array([3.3467026e-05], dtype=float32),
#  array([0.00066065], dtype=float32),
#  array([0.9814305], dtype=float32),
#  array([0.00088322], dtype=float32),
#  array([0.0009069], dtype=float32),
#  array([0.11266036], dtype=float32),
#  array([0.00239573], dtype=float32),
#  array([0.44967288], dtype=float32),
#  array([0.02797004], dtype=float32),
#  array([0.8971769], dtype=float32),
#  array([0.6539384], dtype=float32),
#  array([0.00052445], dtype=float32),
#  array([0.6908011], dtype=float32),
#  array([0.54842573], dtype=float32),
#  array([0.98122185], dtype=float32),
#  array([0.00017118], dtype=float32),
#  array([0.3648253], dtype=float32),
#  array([0.02311043], dtype=float32),
#  array([0.07809436], dtype=float32),
#  array([0.82361776], dtype=float32),
#  array([0.00188264], dtype=float32),
#  array([0.00036638], dtype=float32),
#  array([0.01309708], dtype=float32),
#  array([0.01921781], dtype=float32),
#  array([0.00056644], dtype=float32),
#  array([0.01673975], dtype=float32),
#  array([0.01243259], dtype=float32),
#  array([0.00459382], dtype=float32),
#  array([0.40474364], dtype=float32),
#  array([0.0009999], dtype=float32),
#  array([0.00023607], dtype=float32),
#  array([0.00012913], dtype=float32),
#  array([0.01565627], dtype=float32),
#  array([0.501729], dtype=float32),
#  array([0.01545895], dtype=float32),
#  array([0.00108186], dtype=float32),
#  array([0.9724125], dtype=float32),
#  array([0.00543844], dtype=float32),
#  array([0.00470586], dtype=float32),
#  array([0.42440355], dtype=float32),
#  array([0.04140284], dtype=float32),
#  array([0.98122185], dtype=float32),
#  array([0.5971798], dtype=float32),
#  array([0.02219735], dtype=float32),
#  array([0.00705749], dtype=float32),
#  array([0.03659508], dtype=float32),
#  array([0.04150855], dtype=float32),
#  array([0.09129824], dtype=float32),
#  array([0.94395405], dtype=float32),
#  array([0.9336685], dtype=float32),
#  array([0.00816704], dtype=float32),
#  array([0.02008556], dtype=float32),
#  array([0.4980112], dtype=float32),
#  array([0.00606618], dtype=float32),
#  array([0.02518086], dtype=float32),
#  array([0.01554765], dtype=float32),
#  array([0.00992408], dtype=float32),
#  array([0.03845077], dtype=float32),
#  array([0.00044408], dtype=float32),
#  array([0.42386505], dtype=float32),
#  array([0.10098802], dtype=float32),
#  array([0.03087636], dtype=float32),
#  array([0.00135291], dtype=float32),
#  array([0.00268792], dtype=float32),
#  array([0.757403], dtype=float32),
#  array([0.04009831], dtype=float32),
#  array([0.94385505], dtype=float32),
#  array([0.8733349], dtype=float32),
#  array([0.00162322], dtype=float32),
#  array([0.00025107], dtype=float32),
#  array([0.01207448], dtype=float32),
#  array([0.00680891], dtype=float32),
#  array([0.00269973], dtype=float32),
#  array([0.7556167], dtype=float32),
#  array([0.08578742], dtype=float32),
#  array([0.02082653], dtype=float32),
#  array([0.00038856], dtype=float32),
#  array([0.01301677], dtype=float32),
#  array([0.01070314], dtype=float32),
#  array([0.56690496], dtype=float32),
#  array([0.02131019], dtype=float32),
#  array([0.15457667], dtype=float32),
#  array([0.905852], dtype=float32),
#  array([0.00269638], dtype=float32),
#  array([0.8175955], dtype=float32),
#  array([0.05529305], dtype=float32),
#  array([0.00011761], dtype=float32),
#  array([0.87758785], dtype=float32),
#  array([0.27272877], dtype=float32),
#  array([0.80454886], dtype=float32),
#  array([0.02182197], dtype=float32),
#  array([0.93613577], dtype=float32),
#  array([0.44946453], dtype=float32),
#  array([0.42960808], dtype=float32),
#  array([0.00047174], dtype=float32),
#  array([0.20757675], dtype=float32),
#  array([0.01783316], dtype=float32),
#  array([0.20018014], dtype=float32),
#  array([0.51129293], dtype=float32),
#  array([0.00240772], dtype=float32),
#  array([0.00290469], dtype=float32),
#  array([0.08510203], dtype=float32),
#  array([0.01140776], dtype=float32),
#  array([0.08236283], dtype=float32),
#  ...]

# %%
for i in range(res.shape[0]):
    res[i] = adj(res[i],0.3,0.25)

# %%
res
# Out:
# array([[0.69684035],
#        [0.50893277],
#        [0.55339205],
#        ...,
#        [0.97725713],
#        [0.8812874 ],
#        [0.974749  ]], dtype=float32)

# %%
train_pred_results.extend(res)

# %%
train_pred_results = pd.DataFrame(train_pred_results)
#test['pred'] = res
#test[['pred']].to_csv('cnnresult.txt', index = None, header = None)
train_pred_results.to_csv('cnn2result.dat',index = None)

# %%
len(res)
# Out:
# 5000

# %%
len(res[np.where(res == 0)])
# Out:
# 0

# %%
len(np.unique(test['spa_qura1']))
# Out:
# 3199

# %%
len(np.unique(test['spa_qura2']))
# Out:
# 2695

# %%
len(np.unique(train['spa_qura1']))
# Out:
# 3540

# %%
len(np.unique(train['spa_qura2']))
# Out:
# 5979

# %%
def aveResult(result_array_list):
    final = sum(result_array_list)/len(result_array_list)
    print(np.mean(final))
    final = pd.DataFrame(final)
    final.to_csv('result_.txt', index = None, header = None)

# %%
cv = [cv0,cv5]
aveResult(cv)

# %%
xgb = pd.read_csv('result&gbdt.txt',header = None)
xgb.describe()
# Out:
#                  0
# count  5000.000000
# mean      0.248454
# std       0.269926
# min       0.004539
# 25%       0.056728
# 50%       0.129305
# 75%       0.337693
# max       0.996406

# %%
np.mean(cv5)
# Out:
# 0.24845433020000002

# %%
train = pd.read_csv('Are-you-happy/traditional_model/train.dat')
train.sentence_distance.head()
# Out:
# 0    0.227921
# 1    0.336336
# 2    0.286039
# 3    0.204124
# 4    0.474342
# Name: sentence_distance, dtype: float64

# %%
df = pd.DataFrame()
df['sentence_distance'] = train['sentence_distance']
df['sentence_distance_tfidf'] = train['sentence_distance_tfidf']
df.to_csv('sentence_sim_feature.dat',index = False)

# %%
import pandas as pd
import numpy as np
#df = pd.read_csv('train.dat')
#gbdt = pd.read_csv('result/result_gbdt.txt',header = None)
cnn_gbdt = pd.read_csv('../diff_traditional/result_gbdt.txt',header=None)
#gbdt_sim = pd.read_csv('result/result_gbdt&sim.txt',header=None)

# %%
aa = pd.read_csv('../diff_traditional/train.dat')

# %%
aa.sentence_similarity.head()
# Out:
# 0    0.830081
# 1    0.894331
# 2    0.750192
# 3    0.608729
# 4    0.864632
# Name: sentence_similarity, dtype: float64

# %%
cnn_gbdt.mean()
# Out:
# 0          0.253756
# rescale    0.286122
# dtype: float64

# %%
gbdt_sim.mean()
# Out:
# 0          0.244274
# rescale    0.274023
# dtype: float64

# %%
def adj(x, te, tr):
        a = te / tr
        b = (1 - te) / (1 - tr)
        return a * x / (a * x + b * (1 - x))

# %%
res = pd.DataFrame(res)

# %%
res['rescale'] = res.apply(lambda x:adj(x[0],0.3,0.25),axis=1)

# %%
res.mean()
# Out:
# 0          0.193541
# rescale    0.216799
# dtype: float64

# %%
res['rescale'].to_csv('result_cnn2_rescale.txt',index = False, header = None)

# %%
#gbdt_sim['rescale'] = gbdt_sim.apply(lambda x:adj(x,0.3,0.25),axis=1)
cnn_gbdt['rescale'] = cnn_gbdt.apply(lambda x:adj(x[0],0.3,0.25),axis=1)

# %%
gbdt_sim['rescale'].to_csv('result_gbdt_sim_rescale.txt',index = False,header = None)

# %%
cnn_gbdt['rescale'].to_csv('result_gbdt_cnn2_rescale.txt',index = False,header = None)

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
df = pd.read_csv('../diff_traditional/train.dat')
distance_feature = df[['len_char_s1','len_char_s2','fuzz_QRatio','fuzz_WRatio','sentence_distance_tfidf',
    'cosine_distance_ave_idf','skew_s1vec_ave_idf', 'skew_s2vec_ave_idf', 'kur_s1vec_ave_idf',
       'kur_s2vec_ave_idf']]
distance_feature = np.array(distance_feature)
# Out:
# Index(['label', 'sentences', 'len_word_s1', 'len_word_s2', 'len_ratio',
#        'len_char_s1', 'len_char_s2', 'fuzz_QRatio', 'fuzz_WRatio',
#        'fuzz_partial_ratio', 'fuzz_partial_token_set_ratio',
#        'fuzz_partial_token_sort_ratio', 'fuzz_token_set_ratio',
#        'fuzz_token_sort_ratio', 'long_common_sequence', 'long_common_prefix',
#        'long_common_suffix', 'long_common_substring', 'levenshtein_distance',
#        'sentence_similarity', 'has_no_word', 'sentence_distance',
#        'sentence_distance_tfidf', 'lcs_diff', 'cnn_result',
#        '1-gramoverlap_word', '2-gramoverlap_word', '3-gramoverlap_word',
#        '2-gramoverlap_char', '3-gramoverlap_char', '4-gramoverlap_char',
#        '5-gramoverlap_char', 'jaccard_distance_ave_idf',
#        'cosine_distance_ave_idf', 'canberra_distance_ave_idf',
#        'euclidean_distance_ave_idf', 'braycurtis_distance_ave_idf',
#        'minkowski_distance_ave_idf', 'pearson_coff_ave_idf',
#        'spearman_coff_ave_idf', 'kendalltau_coff_ave_idf',
#        'skew_s1vec_ave_idf', 'skew_s2vec_ave_idf', 'kur_s1vec_ave_idf',
#        'kur_s2vec_ave_idf'],
#       dtype='object')

# %%
distance_feature = df[['len_char_s1','len_char_s2','fuzz_QRatio','fuzz_WRatio','sentence_distance_tfidf',
    'cosine_distance_ave_idf','skew_s1vec_ave_idf', 'skew_s2vec_ave_idf', 'kur_s1vec_ave_idf',
       'kur_s2vec_ave_idf']]

# %%
distance_feature = np.array(distance_feature)
distance_feature[:2]
# Out:
# array([[32.        , 62.        , 39.        , 86.        ,  0.22545252,
#          0.25577446, -0.19645793, -0.35475846,  0.10816221,  0.52349916],
#        [86.        , 67.        , 31.        , 54.        ,  0.19932241,
#          0.12921127, -0.43639298, -0.35495612,  1.16359401,  0.8015316 ]])
